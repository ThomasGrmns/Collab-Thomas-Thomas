# %% [markdown]
# ### 2010B Three Brothers

# %% [markdown]
# ![afbeelding.png](attachment:35fb0133-8c0e-4441-9ee1-f102ca3a091f.png)

# %% [markdown]
# https://codeforces.com/problemset/problem/2010/B

# %%
brothersPresent = input().split(" ")
allBrothers = ["1", "2", "3"]
for brother in allBrothers:
    if brother in brothersPresent:
        continue
    else:
        print(brother)
# Out:
#  2 3
# 1
