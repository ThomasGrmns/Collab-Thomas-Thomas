# %% [markdown]
# ### 25A IQ Test

# %% [markdown]
# ![afbeelding.png](attachment:554e8c73-a1e0-4feb-93ac-39d77723d591.png)

# %% [markdown]
# https://codeforces.com/problemset/problem/25/A

# %%
def isEven(x):
    isEven = False
    if int(x) % 2 == 0:
        isEven = True
    return isEven

testCount = int((input().split())[0])
testNumbers = input().split(" ")
evensCount = 0

#Eerste 3 getallen nakijken
for i in range(3):
    if isEven(testNumbers[i]):
        evensCount += 1

if evensCount >= 2:
    for j in range(testCount+1):
        if isEven(testNumbers[j]) == False:
            print(j+1)
            break
else:
    for j in range(testCount+1):
        if isEven(testNumbers[j]) == True:
            print(j+1)
            break
# Out:
#  4
#  1 2 1 1
# 2
