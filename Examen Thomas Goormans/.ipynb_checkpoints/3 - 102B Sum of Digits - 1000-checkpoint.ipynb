# %% [markdown]
# ### 102B - Sum of Digits

# %% [markdown]
# ![afbeelding.png](attachment:ad1bbf19-7b73-49e8-b9db-06068c28aa14.png)

# %% [markdown]
# https://codeforces.com/problemset/problem/102/B

# %%
def addNumbers(myNumber):
    numberDigits = []
    numberString = str(myNumber)
    for i in numberString:
        numberDigits.append(int(i))
    return sum(numberDigits)

number = input()
myNumber = int(number)
magicPerformed = 0
while myNumber > 9:
    myNumber = addNumbers(myNumber)
    magicPerformed += 1
print(magicPerformed)
# Out:
#  991
# 3

# %%
def addNumbers(myNumber):
    numberDigits = []
    numberString = str(myNumber)
    for i in numberString:
        numberDigits.append(int(i))
    return sum(numberDigits)

# %%
addNumbers(40605)
# Out:
# 15
