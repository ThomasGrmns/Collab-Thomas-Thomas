# %% [markdown]
# ### 579A Raising Bacteria

# %% [markdown]
# ![afbeelding.png](attachment:8edd311a-45c4-4c28-911e-76bbfd84f36b.png)

# %% [markdown]
# https://codeforces.com/problemset/problem/579/A

# %%
a = input()
b = int(a)
c = 0
while b > 0:
    if b % 2 == 0:
        b = b/2
    else:
        b = b-1
        c += 1
print(c)
# Out:
#  5
# 2
